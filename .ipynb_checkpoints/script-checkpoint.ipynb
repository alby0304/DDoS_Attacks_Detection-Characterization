# %% [markdown]
# # DDoS Attacks Detection and Characterization

# %% [markdown]
# Import pyton libraries

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import datetime

# %%
df = pd.read_csv('ddos_dataset.csv')

df_copy = df.copy()
# Out:
# /tmp/ipykernel_15327/3984028547.py:1: DtypeWarning: Columns (85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ddos_dataset.csv')

# %% [markdown]
# ## Section 1 – Data exploration and pre-processing

# %%
#Fix column names
df.columns = [col.strip().replace(" ", "") for col in df.columns] 

#Drop unnecessary columns 
df.drop(columns=['FlowID'],inplace=True)
df.drop(columns=['Unnamed:0'],inplace=True)

#Fix similarHTTP column values
df['SimillarHTTP'] = df['SimillarHTTP'].apply(lambda x : 1 if x != 0 else 0)
print(df['SimillarHTTP'].value_counts())
# Out:
# SimillarHTTP
# 1    40960
# 0    23279
# Name: count, dtype: int64

# %%
#Int this section we remove columns that have the same value in every row (no variability), since they are meanningless for the analysis or modeling
#We can notice that 12 columns have just one unique value, so we went from 88 columns to 76 columns 

#unique values per column
uniqueVpc = df.apply(lambda col: col.unique())

#Columns with just one unique value
cwov = uniqueVpc[uniqueVpc.apply(len) == 1].index

print("Columns meaningless beacuse they have the same value on all rows:")
print(cwov)

df = df.drop(columns=cwov)

df.info()
# Out:
# Columns meaningless beacuse they have the same value on all rows:
# Index(['BwdPSHFlags', 'FwdURGFlags', 'BwdURGFlags', 'FINFlagCount',
#        'PSHFlagCount', 'ECEFlagCount', 'FwdAvgBytes/Bulk',
#        'FwdAvgPackets/Bulk', 'FwdAvgBulkRate', 'BwdAvgBytes/Bulk',
#        'BwdAvgPackets/Bulk', 'BwdAvgBulkRate'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64239 entries, 0 to 64238
# Data columns (total 76 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed:0                64239 non-null  int64
#  1   FlowID                   64239 non-null  object
#  2   SourceIP                 64239 non-null  object
#  3   SourcePort               64239 non-null  int64
#  4   DestinationIP            64239 non-null  object
#  5   DestinationPort          64239 non-null  int64
#  6   Protocol                 64239 non-null  int64
#  7   Timestamp                64239 non-null  object
#  8   FlowDuration             64239 non-null  int64
#  9   TotalFwdPackets          64239 non-null  int64
#  10  TotalBackwardPackets     64239 non-null  int64
#  11  TotalLengthofFwdPackets  64239 non-null  float64
#  12  TotalLengthofBwdPackets  64239 non-null  float64
#  13  FwdPacketLengthMax       64239 non-null  float64
#  14  FwdPacketLengthMin       64239 non-null  float64
#  15  FwdPacketLengthMean      64239 non-null  float64
#  16  FwdPacketLengthStd       64239 non-null  float64
#  17  BwdPacketLengthMax       64239 non-null  float64
#  18  BwdPacketLengthMin       64239 non-null  float64
#  19  BwdPacketLengthMean      64239 non-null  float64
#  20  BwdPacketLengthStd       64239 non-null  float64
#  21  FlowBytes/s              64239 non-null  float64
#  22  FlowPackets/s            64239 non-null  float64
#  23  FlowIATMean              64239 non-null  float64
#  24  FlowIATStd               64239 non-null  float64
#  25  FlowIATMax               64239 non-null  float64
#  26  FlowIATMin               64239 non-null  float64
#  27  FwdIATTotal              64239 non-null  float64
#  28  FwdIATMean               64239 non-null  float64
#  29  FwdIATStd                64239 non-null  float64
#  30  FwdIATMax                64239 non-null  float64
#  31  FwdIATMin                64239 non-null  float64
#  32  BwdIATTotal              64239 non-null  float64
#  33  BwdIATMean               64239 non-null  float64
#  34  BwdIATStd                64239 non-null  float64
#  35  BwdIATMax                64239 non-null  float64
#  36  BwdIATMin                64239 non-null  float64
#  37  FwdPSHFlags              64239 non-null  int64
#  38  FwdHeaderLength          64239 non-null  int64
#  39  BwdHeaderLength          64239 non-null  int64
#  40  FwdPackets/s             64239 non-null  float64
#  41  BwdPackets/s             64239 non-null  float64
#  42  MinPacketLength          64239 non-null  float64
#  43  MaxPacketLength          64239 non-null  float64
#  44  PacketLengthMean         64239 non-null  float64
#  45  PacketLengthStd          64239 non-null  float64
#  46  PacketLengthVariance     64239 non-null  float64
#  47  SYNFlagCount             64239 non-null  int64
#  48  RSTFlagCount             64239 non-null  int64
#  49  ACKFlagCount             64239 non-null  int64
#  50  URGFlagCount             64239 non-null  int64
#  51  CWEFlagCount             64239 non-null  int64
#  52  Down/UpRatio             64239 non-null  float64
#  53  AveragePacketSize        64239 non-null  float64
#  54  AvgFwdSegmentSize        64239 non-null  float64
#  55  AvgBwdSegmentSize        64239 non-null  float64
#  56  FwdHeaderLength.1        64239 non-null  int64
#  57  SubflowFwdPackets        64239 non-null  int64
#  58  SubflowFwdBytes          64239 non-null  int64
#  59  SubflowBwdPackets        64239 non-null  int64
#  60  SubflowBwdBytes          64239 non-null  int64
#  61  Init_Win_bytes_forward   64239 non-null  int64
#  62  Init_Win_bytes_backward  64239 non-null  int64
#  63  act_data_pkt_fwd         64239 non-null  int64
#  64  min_seg_size_forward     64239 non-null  int64
#  65  ActiveMean               64239 non-null  float64
#  66  ActiveStd                64239 non-null  float64
#  67  ActiveMax                64239 non-null  float64
#  68  ActiveMin                64239 non-null  float64
#  69  IdleMean                 64239 non-null  float64
#  70  IdleStd                  64239 non-null  float64
#  71  IdleMax                  64239 non-null  float64
#  72  IdleMin                  64239 non-null  float64
#  73  SimillarHTTP             64239 non-null  int64
#  74  Inbound                  64239 non-null  int64
#  75  label                    64239 non-null  object
# dtypes: float64(45), int64(26), object(5)
# memory usage: 37.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64239 entries, 0 to 64238
# Data columns (total 88 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed:0                64239 non-null  int64
#  1   FlowID                   64239 non-null  object
#  2   SourceIP                 64239 non-null  object
#  3   SourcePort               64239 non-null  int64
#  4   DestinationIP            64239 non-null  object
#  5   DestinationPort          64239 non-null  int64
#  6   Protocol                 64239 non-null  int64
#  7   Timestamp                64239 non-null  object
#  8   FlowDuration             64239 non-null  int64
#  9   TotalFwdPackets          64239 non-null  int64
#  10  TotalBackwardPackets     64239 non-null  int64
#  11  TotalLengthofFwdPackets  64239 non-null  float64
#  12  TotalLengthofBwdPackets  64239 non-null  float64
#  13  FwdPacketLengthMax       64239 non-null  float64
#  14  FwdPacketLengthMin       64239 non-null  float64
#  15  FwdPacketLengthMean      64239 non-null  float64
#  16  FwdPacketLengthStd       64239 non-null  float64
#  17  BwdPacketLengthMax       64239 non-null  float64
#  18  BwdPacketLengthMin       64239 non-null  float64
#  19  BwdPacketLengthMean      64239 non-null  float64
#  20  BwdPacketLengthStd       64239 non-null  float64
#  21  FlowBytes/s              64239 non-null  float64
#  22  FlowPackets/s            64239 non-null  float64
#  23  FlowIATMean              64239 non-null  float64
#  24  FlowIATStd               64239 non-null  float64
#  25  FlowIATMax               64239 non-null  float64
#  26  FlowIATMin               64239 non-null  float64
#  27  FwdIATTotal              64239 non-null  float64
#  28  FwdIATMean               64239 non-null  float64
#  29  FwdIATStd                64239 non-null  float64
#  30  FwdIATMax                64239 non-null  float64
#  31  FwdIATMin                64239 non-null  float64
#  32  BwdIATTotal              64239 non-null  float64
#  33  BwdIATMean               64239 non-null  float64
#  34  BwdIATStd                64239 non-null  float64
#  35  BwdIATMax                64239 non-null  float64
#  36  BwdIATMin                64239 non-null  float64
#  37  FwdPSHFlags              64239 non-null  int64
#  38  BwdPSHFlags              64239 non-null  int64
#  39  FwdURGFlags              64239 non-null  int64
#  40  BwdURGFlags              64239 non-null  int64
#  41  FwdHeaderLength          64239 non-null  int64
#  42  BwdHeaderLength          64239 non-null  int64
#  43  FwdPackets/s             64239 non-null  float64
#  44  BwdPackets/s             64239 non-null  float64
#  45  MinPacketLength          64239 non-null  float64
#  46  MaxPacketLength          64239 non-null  float64
#  47  PacketLengthMean         64239 non-null  float64
#  48  PacketLengthStd          64239 non-null  float64
#  49  PacketLengthVariance     64239 non-null  float64
#  50  FINFlagCount             64239 non-null  int64
#  51  SYNFlagCount             64239 non-null  int64
#  52  RSTFlagCount             64239 non-null  int64
#  53  PSHFlagCount             64239 non-null  int64
#  54  ACKFlagCount             64239 non-null  int64
#  55  URGFlagCount             64239 non-null  int64
#  56  CWEFlagCount             64239 non-null  int64
#  57  ECEFlagCount             64239 non-null  int64
#  58  Down/UpRatio             64239 non-null  float64
#  59  AveragePacketSize        64239 non-null  float64
#  60  AvgFwdSegmentSize        64239 non-null  float64
#  61  AvgBwdSegmentSize        64239 non-null  float64
#  62  FwdHeaderLength.1        64239 non-null  int64
#  63  FwdAvgBytes/Bulk         64239 non-null  int64
#  64  FwdAvgPackets/Bulk       64239 non-null  int64
#  65  FwdAvgBulkRate           64239 non-null  int64
#  66  BwdAvgBytes/Bulk         64239 non-null  int64
#  67  BwdAvgPackets/Bulk       64239 non-null  int64
#  68  BwdAvgBulkRate           64239 non-null  int64
#  69  SubflowFwdPackets        64239 non-null  int64
#  70  SubflowFwdBytes          64239 non-null  int64
#  71  SubflowBwdPackets        64239 non-null  int64
#  72  SubflowBwdBytes          64239 non-null  int64
#  73  Init_Win_bytes_forward   64239 non-null  int64
#  74  Init_Win_bytes_backward  64239 non-null  int64
#  75  act_data_pkt_fwd         64239 non-null  int64
#  76  min_seg_size_forward     64239 non-null  int64
#  77  ActiveMean               64239 non-null  float64
#  78  ActiveStd                64239 non-null  float64
#  79  ActiveMax                64239 non-null  float64
#  80  ActiveMin                64239 non-null  float64
#  81  IdleMean                 64239 non-null  float64
#  82  IdleStd                  64239 non-null  float64
#  83  IdleMax                  64239 non-null  float64
#  84  IdleMin                  64239 non-null  float64
#  85  SimillarHTTP             64239 non-null  int64
#  86  Inbound                  64239 non-null  int64
#  87  label                    64239 non-null  object
# dtypes: float64(45), int64(38), object(5)
# memory usage: 43.1+ MB

# %%
df.describe()
# Out:
#           Unnamed:0    SourcePort  DestinationPort      Protocol  \
# count  64239.000000  64239.000000     64239.000000  64239.000000
# mean   32637.819876  25267.368608     30715.252884     14.362864
# std    19008.473731  24710.413442     20347.990914      4.706001
# min        0.000000      0.000000         0.000000      0.000000
# 25%    16209.500000    779.000000     12435.500000     17.000000
# 50%    32477.000000  29661.000000     30797.000000     17.000000
# 75%    48726.500000  48510.500000     49041.500000     17.000000
# max    65999.000000  65518.000000     65535.000000     17.000000
#
#        FlowDuration  TotalFwdPackets  TotalBackwardPackets  \
# count  6.423900e+04     64239.000000          64239.000000
# mean   5.150614e+06        18.814848              1.304036
# std    2.249713e+07       462.305336             25.199720
# min    1.000000e+00         1.000000              0.000000
# 25%    1.000000e+00         2.000000              0.000000
# 50%    2.000000e+00         2.000000              0.000000
# 75%    2.087700e+04         2.000000              0.000000
# max    1.200000e+08     85894.000000           1862.000000
#
#        TotalLengthofFwdPackets  TotalLengthofBwdPackets  FwdPacketLengthMax  \
# count             64239.000000             6.423900e+04        64239.000000
# mean               6699.521630             2.153348e+03          613.992948
# std               20510.320389             9.087201e+04          585.691655
# min                   0.000000             0.000000e+00            0.000000
# 25%                 123.000000             0.000000e+00           53.000000
# 50%                1050.000000             0.000000e+00          393.000000
# 75%                2944.000000             0.000000e+00         1464.000000
# max              176000.000000             8.829488e+06         3564.000000
#
#        ...  min_seg_size_forward    ActiveMean     ActiveStd     ActiveMax  \
# count  ...          6.423900e+04  6.423900e+04  6.423900e+04  6.423900e+04
# mean   ...         -4.167229e+07  9.026629e+03  4.878774e+03  1.687791e+04
# std    ...          2.062767e+08  2.045563e+05  1.424082e+05  3.828583e+05
# min    ...         -1.062719e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...         -1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    ...          1.400000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    ...          2.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# max    ...          1.480000e+03  1.678654e+07  2.853681e+07  6.783473e+07
#
#           ActiveMin      IdleMean       IdleStd       IdleMax       IdleMin  \
# count  6.423900e+04  6.423900e+04  6.423900e+04  6.423900e+04  6.423900e+04
# mean   6.204895e+03  1.155553e+06  2.613584e+05  1.555321e+06  8.908522e+05
# std    1.667756e+05  5.341380e+06  1.574889e+06  6.993415e+06  4.571276e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    8.349846e+06  1.147455e+08  5.275036e+07  1.147455e+08  1.147455e+08
#
#             Inbound
# count  64239.000000
# mean       0.919566
# std        0.271966
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 82 columns]

# %% [markdown]
# ### BASIC TRAFFIC STATISTICS

# %%
n_src_ip = df["SourceIP"].nunique()
n_dst_ip = df["DestinationIP"].nunique()

print(f"Number of unique source IPs: {n_src_ip}")
print(f"Number of unique destination IPs: {n_dst_ip}")
# Out:
# Number of unique source IPs: 216
# Number of unique destination IPs: 245

# %% [markdown]
# ### CLASS DISTRIBUTION

# %%
labels = df["label"].unique()

# n_benign = df[df["label"] == 'benign'].shape[0] 
# print(f"Number of benign packets: {n_benign}")
# n_benign_flows = df[df["label"] == 'benign'].groupby("FlowID").count().shape[0]
# print(f"Number of benign flows: {n_benign_flows}")

n_attack_per_label = {}
for label in labels:
    n_attack_per_label[label] = df[df["label"] == label].shape[0]

print(n_attack_per_label)

plot_df_n_labels = pd.DataFrame({
    'Number of attacked packets': n_attack_per_label,
})


plot_df_n_labels.plot(kind='bar')
plt.title('Distribuition of flow labels')
plt.xlabel('Flow Labels')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# {'ddos_dns': 5369, 'benign': 5658, 'ddos_ldap': 5928, 'ddos_mssql': 5911, 'ddos_netbios': 5830, 'ddos_ntp': 986, 'ddos_snmp': 5984, 'ddos_ssdp': 5970, 'ddos_udp': 5876, 'ddos_syn': 5480, 'ddos_tftp': 5261, 'ddos_udp_lag': 5986}

# %% [markdown]
# ## Categorial features encoding

# %%
#Funzione per convertire IP in intero, qui convertiamo i source ip
def ip_to_int(ip):
    try:
        # Funziona sia per IPv4 che per IPv6
        return int(ipaddress.ip_address(ip))
    except:
        # Se c'è un errore (es. valore nullo o stringa errata), ritorna None o -1
        return None

#Applicare la funzione alla colonna 'Src IP'
df['SourceIpInt'] = df['SourceIP'].apply(ip_to_int)
df['DestinationIPInt'] = df['DestinationIP'].apply(ip_to_int)

print(df[['SourceIP', 'SourceIpInt']].head())
print(df[['DestinationIP', 'DestinationIPInt']].head())

df.info()
#si creeranno due colonne nuove con gli IP convertiti in interi

#Convert 'Timestamp' to seconds since the first timestamp
reference_date = min(df['Timestamp'])
df['Timestamp'] = (df['Timestamp']-reference_date).dt.total_seconds()
# Out:
#        SourceIP SourceIpInt
# 0    172.16.0.5        None
# 1  192.168.50.1        None
# 2    172.16.0.5        None
# 3    172.16.0.5        None
# 4    172.16.0.5        None
#   DestinationIP DestinationIPInt
# 0  192.168.50.1             None
# 1    172.16.0.5             None
# 2  192.168.50.1             None
# 3  192.168.50.1             None
# 4  192.168.50.1             None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64239 entries, 0 to 64238
# Data columns (total 78 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed:0                64239 non-null  int64
#  1   FlowID                   64239 non-null  object
#  2   SourceIP                 64239 non-null  object
#  3   SourcePort               64239 non-null  int64
#  4   DestinationIP            64239 non-null  object
#  5   DestinationPort          64239 non-null  int64
#  6   Protocol                 64239 non-null  int64
#  7   Timestamp                64239 non-null  object
#  8   FlowDuration             64239 non-null  int64
#  9   TotalFwdPackets          64239 non-null  int64
#  10  TotalBackwardPackets     64239 non-null  int64
#  11  TotalLengthofFwdPackets  64239 non-null  float64
#  12  TotalLengthofBwdPackets  64239 non-null  float64
#  13  FwdPacketLengthMax       64239 non-null  float64
#  14  FwdPacketLengthMin       64239 non-null  float64
#  15  FwdPacketLengthMean      64239 non-null  float64
#  16  FwdPacketLengthStd       64239 non-null  float64
#  17  BwdPacketLengthMax       64239 non-null  float64
#  18  BwdPacketLengthMin       64239 non-null  float64
#  19  BwdPacketLengthMean      64239 non-null  float64
#  20  BwdPacketLengthStd       64239 non-null  float64
#  21  FlowBytes/s              64239 non-null  float64
#  22  FlowPackets/s            64239 non-null  float64
#  23  FlowIATMean              64239 non-null  float64
#  24  FlowIATStd               64239 non-null  float64
#  25  FlowIATMax               64239 non-null  float64
#  26  FlowIATMin               64239 non-null  float64
#  27  FwdIATTotal              64239 non-null  float64
#  28  FwdIATMean               64239 non-null  float64
#  29  FwdIATStd                64239 non-null  float64
#  30  FwdIATMax                64239 non-null  float64
#  31  FwdIATMin                64239 non-null  float64
#  32  BwdIATTotal              64239 non-null  float64
#  33  BwdIATMean               64239 non-null  float64
#  34  BwdIATStd                64239 non-null  float64
#  35  BwdIATMax                64239 non-null  float64
#  36  BwdIATMin                64239 non-null  float64
#  37  FwdPSHFlags              64239 non-null  int64
#  38  FwdHeaderLength          64239 non-null  int64
#  39  BwdHeaderLength          64239 non-null  int64
#  40  FwdPackets/s             64239 non-null  float64
#  41  BwdPackets/s             64239 non-null  float64
#  42  MinPacketLength          64239 non-null  float64
#  43  MaxPacketLength          64239 non-null  float64
#  44  PacketLengthMean         64239 non-null  float64
#  45  PacketLengthStd          64239 non-null  float64
#  46  PacketLengthVariance     64239 non-null  float64
#  47  SYNFlagCount             64239 non-null  int64
#  48  RSTFlagCount             64239 non-null  int64
#  49  ACKFlagCount             64239 non-null  int64
#  50  URGFlagCount             64239 non-null  int64
#  51  CWEFlagCount             64239 non-null  int64
#  52  Down/UpRatio             64239 non-null  float64
#  53  AveragePacketSize        64239 non-null  float64
#  54  AvgFwdSegmentSize        64239 non-null  float64
#  55  AvgBwdSegmentSize        64239 non-null  float64
#  56  FwdHeaderLength.1        64239 non-null  int64
#  57  SubflowFwdPackets        64239 non-null  int64
#  58  SubflowFwdBytes          64239 non-null  int64
#  59  SubflowBwdPackets        64239 non-null  int64
#  60  SubflowBwdBytes          64239 non-null  int64
#  61  Init_Win_bytes_forward   64239 non-null  int64
#  62  Init_Win_bytes_backward  64239 non-null  int64
#  63  act_data_pkt_fwd         64239 non-null  int64
#  64  min_seg_size_forward     64239 non-null  int64
#  65  ActiveMean               64239 non-null  float64
#  66  ActiveStd                64239 non-null  float64
#  67  ActiveMax                64239 non-null  float64
#  68  ActiveMin                64239 non-null  float64
#  69  IdleMean                 64239 non-null  float64
#  70  IdleStd                  64239 non-null  float64
#  71  IdleMax                  64239 non-null  float64
#  72  IdleMin                  64239 non-null  float64
#  73  SimillarHTTP             64239 non-null  int64
#  74  Inbound                  64239 non-null  int64
#  75  label                    64239 non-null  object
#  76  SourceIpInt              0 non-null      object
#  77  DestinationIPInt         0 non-null      object
# dtypes: float64(45), int64(26), object(7)
# memory usage: 38.2+ MB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 22
#      18 #si creeranno due colonne nuove con gli IP convertiti in interi
#      19
#      20 #Convert 'Timestamp' to seconds since the first timestamp
#      21 reference_date = min(df['Timestamp'])
# ---> 22 df['Timestamp'] = (df['Timestamp'] - reference_date).dt.total_seconds()
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/series.py:6154, in Series._arith_method(self, other, op)
#    6152 def _arith_method(self, other, op):
#    6153     self, other = self._align_for_op(other)
# -> 6154     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/base.py:1391, in IndexOpsMixin._arith_method(self, other, op)
#    1388     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1390 with np.errstate(all="ignore"):
# -> 1391     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1393 return self._construct_result(result, name=res_name)
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)    225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~/Documents/poliTO/ML4N/DDoS_Attacks_Detection-Characterization/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
